# %%
# installing ultralytics library for yolo
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.3/41.3 kB 2.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 863.7/863.7 kB 14.0 MB/s eta 0:00:00a 0:00:01
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2
import os
from ultralytics import YOLO

# %%
# Load a model
model = YOLO("yolov8n.yaml")  # build a new model from YAML
model = YOLO("yolov8n.pt")  # load a pretrained model (recommended for training)
model = YOLO("yolov8n.yaml").load("yolov8n.pt")  # build from YAML and transfer weights

# Train the model
results = model.train(data="/kaggle/input/cardetection/car/data.yaml", epochs=40, imgsz=480, batch=128, optimizer="Adam", dropout=0.3)
# Out:
# ...
# 100%|██████████| 6.25M/6.25M [00:00<00:00, 73.1MB/s]
# Transferred 355/355 items from pretrained weights
# Ultralytics YOLOv8.2.71 🚀 Python-3.10.13 torch-2.1.2 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
test_images_dir = '/kaggle/input/cardetection/car/test/images'

# %%
os.mkdir('/kaggle/working/Results')

# %%
results = model(test_images_dir)
i = 0
for result in results:
    boxes = result.boxes
    predictions = result.probs
    result.save(filename=f'/kaggle/working/Results/results_{i}.jpg')
    i += 1
# Out:
# image 1/638 /kaggle/input/cardetection/car/test/images/000003_jpg.rf.8511b9c219dbf9799a6d58900b15917d.jpg: 480x480 1 Speed Limit 30, 9.8ms
# image 2/638 /kaggle/input/cardetection/car/test/images/000006_jpg.rf.89610ec419ccfab22f8314026b90ee26.jpg: 480x480 1 Speed Limit 30, 7.0ms
# image 3/638 /kaggle/input/cardetection/car/test/images/00000_00000_00003_png.rf.d18afc3c9625ffb1974029d3e3762aee.jpg: 480x480 1 Speed Limit 20, 6.6ms
# image 4/638 /kaggle/input/cardetection/car/test/images/00000_00000_00005_png.rf.ab60a274676963d378f5014e89d9e2b1.jpg: 480x480 1 Speed Limit 20, 6.6ms
# image 5/638 /kaggle/input/cardetection/car/test/images/00000_00000_00006_png.rf.9d1ea68507aff6973a1dbcdc6f4422a8.jpg: 480x480 1 Speed Limit 20, 6.8ms
# image 6/638 /kaggle/input/cardetection/car/test/images/00000_00000_00008_png.rf.ff305dcd6e9ceb9188937311a4a1b207.jpg: 480x480 1 Speed Limit 20, 8.2ms
# ...

# %%
test_images_filenames = os.listdir('/kaggle/working/Results')
test_images_filenames
# Out:
# ['results_516.jpg',
#  'results_174.jpg',
#  'results_290.jpg',
#  'results_114.jpg',
#  'results_361.jpg',
#  'results_151.jpg',
#  'results_572.jpg',
#  'results_549.jpg',
#  'results_211.jpg',
#  'results_526.jpg',
#  'results_312.jpg',
#  'results_582.jpg',
#  'results_390.jpg',
#  'results_379.jpg',
#  'results_392.jpg',
#  'results_522.jpg',
#  'results_267.jpg',
#  'results_6.jpg',
#  'results_235.jpg',
#  'results_401.jpg',
#  'results_458.jpg',
#  'results_279.jpg',
#  'results_176.jpg',
#  'results_524.jpg',
#  'results_111.jpg',
#  'results_31.jpg',
#  'results_215.jpg',
#  'results_473.jpg',
#  'results_598.jpg',
#  'results_308.jpg',
#  'results_261.jpg',
#  'results_369.jpg',
#  'results_486.jpg',
#  'results_594.jpg',
#  'results_116.jpg',
#  'results_319.jpg',
#  'results_287.jpg',
#  'results_492.jpg',
#  'results_120.jpg',
#  'results_619.jpg',
#  'results_81.jpg',
#  'results_355.jpg',
#  'results_466.jpg',
#  'results_382.jpg',
#  'results_250.jpg',
# ...

# %%
test_samples = np.random.choice(test_images_filenames,16)
test_samples
# Out:
# array(['results_367.jpg', 'results_246.jpg', 'results_371.jpg', 'results_161.jpg', 'results_526.jpg', 'results_333.jpg', 'results_60.jpg', 'results_449.jpg', 'results_16.jpg', 'results_38.jpg', 'results_205.jpg', 'results_462.jpg', 'results_49.jpg', 'results_98.jpg', 'results_544.jpg', 'results_303.jpg'], dtype='<U15')

# %%
image_ex_path = os.path.join('/kaggle/working/Results','results_367.jpg')
image_ex_path
# Out:
# '/kaggle/working/Results/results_367.jpg'

# %%
result_dir = '/kaggle/working/Results'

# %%
plt.figure(figsize=(10,10))
i = 1
for image in test_samples:
    image_path = os.path.join(result_dir,image)
    img = plt.imread(image_path)
    plt.subplot(4,4,i)
    plt.axis('off')
    plt.imshow(img)
    i += 1
plt.show()
